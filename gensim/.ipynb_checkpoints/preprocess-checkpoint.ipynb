# %%
import json
import spacy
from collections import Counter

everything = json.loads(open('data.json').read())

# %%
everything[0]['content'][0]
# Out:
# 'How to download copy of Google search history - Business Insider'

# %% [markdown]
# C:/Users/DELL.india/Desktop/activity/data2.json

# %%
# print(everything[0])
# print(everything[1])

# %%
# everything[0]['time']

# %%
len(everything)
# Out:
# 29391

# %%
# filter out empty searches
j=0
empty_indices=[]
for i in range(len(everything)):
    if everything[i]['content']==[]:
#         empty_indices=empty_indices+(str(i))
        empty_indices.append(i)
#         print(list(str(i)))
        j=j+1

# print(j,empty_indices)
# print(len(empty_indices))
# print(j)

# %%
def minus1():
    for i in range(len(empty_indices)):
        empty_indices[i]=empty_indices[i]-1

# %%
for i in empty_indices:
    del everything[i]
    minus1()

# %%
len(everything)
# Out:
# 29181

# %%
content=[]
for i in range(len(everything)):
    content=content+list(everything[i]['content'])

# %%
len(content)
# Out:
# 29181

# %%
# content

# %%
for i in range(len(everything)):
    del everything[i]['time'][0]

# %%
time=[]
for i in range(len(everything)):
    time=time+list(everything[i]['time'])

# %%
len(time)
# Out:
# 29181

# %%
time[0]
# Out:
# 'May 17, 2019, 3:40:43 AM UTC'

# %%
import string
translator = str.maketrans('', '', string.punctuation)
s="hey, punct. - it is awesome!!"
# print(s.translate(translator))
s=s.translate(translator)
print(s)
type(s)
# Out:
# hey punct  it is awesome
# str

# %%
content[0]
# Out:
# 'How to download copy of Google search history - Business Insider'

# %%
# len(everything)
# everything
# content
import string
from nltk.stem.wordnet import WordNetLemmatizer

lemma = WordNetLemmatizer()

translator = str.maketrans('', '', string.punctuation)

for i in range(len(content)):
    content[i]=content[i].translate(translator)
    content[i]=content[i].lower()
    content[i] =" ".join(lemma.lemmatize(word) for word in content[i].split())

# print(content)

# %%
from datetime import datetime
# t1=datetime.strptime('May 17, 2019, 3:50:43 PM UTC', '%b %d, %Y, %I:%M:%S %p %Z')
# t2=datetime.strptime('May 17, 2019, 3:40:43 PM UTC', '%b %d, %Y, %I:%M:%S %p %Z')
# print(t2.minute-t1.minute)

# %%
def diffunder60mins(t1,t2):
    y2=t2.year
    M2=t2.month
    d2=t2.day
    h2=t2.hour
    m2=t2.minute
    y1=t1.year
    M1=t1.month
    d1=t1.day
    h1=t1.hour
    m1=t1.minute
    if(y1==y2 and M1==M2 and d1==d2):
        if(abs(m2-m1+60*(h2-h1))>=60):
            return False
        else:
            return True
    else:
        return False

# %%
# diffunder60mins(t1,t2)

# %%
time_objects=[]
for i in range(len(time)):
    time_objects.append(datetime.strptime(time[i], '%b %d, %Y, %I:%M:%S %p %Z'))

# %%
# time_objects[0].hour

# %%
session_number=[0]
l=len(time_objects)
j=0
for i in range(1,l):
    if(diffunder60mins(time_objects[i-1],time_objects[i])==True):
        session_number.append(j)
    else:
        j=j+1
        session_number.append(j)

# %%
# len(session_number)

# %%
# session_number

# %%
# session_number[-1]

# %%
sessions=[]
session=[[content[0],time[0]]]
# print(session)
k=session_number[0]
# print(k)
for i in range(1,len(content)):
    if(session_number[i]!=k):
        k=session_number[i]
        sessions.append(session)
        session=[]
    if(session_number[i]==k):
        session.append([content[i],time[i]])
if(session!=[]):
    sessions.append(session)

# %%
# print(sessions)

# %%
# len(sessions)

# %%
# sessions[0]

# %%
sessions[1]
# Out:
# [['how to check if you have a dedicated gpu addictivetips',
#   'May 16, 2019, 4:28:22 PM UTC'],
#  ['do i have a gpu', 'May 16, 2019, 4:28:13 PM UTC'],
#  ['whats the difference between a cpu and a gpu the official',
#   'May 16, 2019, 4:27:30 PM UTC'],
#  ['cpu and gpu', 'May 16, 2019, 4:27:20 PM UTC']]

# %%
sessions[10][0][0]
# Out:
# 'luther hochzeit wagner'

# %%
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL.india\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
set(stopwords.words('english'))
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
# example_sent = "This is a sample sentence, showing off the stop words filtration."
  
stop_words = set(stopwords.words('english')) 
  
# word_tokens = word_tokenize(example_sent) 

# filtered_sentence = [w for w in word_tokens if not w in stop_words]

# %%
# (filtered_sentence)

# %%
# print(word_tokens)

# %%
for i in range(len(sessions)):
    for j in range(len(sessions[i])):
        word_tokens = word_tokenize(sessions[i][j][0]) 
        filtered_sentence = [w for w in word_tokens if not w in stop_words]
        sessions[i][j][0]=filtered_sentence

# %%
print(sessions[0])
# Out:
# [[['download', 'copy', 'google', 'search', 'history', 'business', 'insider'], 'May 17, 2019, 3:40:43 AM UTC'], [['download', 'entire', 'google', 'search', 'history', '2', 'easy', 'step'], 'May 17, 2019, 3:40:40 AM UTC'], [['httpssupportgooglecomaccountsanswerdupmfakeanswerid3024190hlen'], 'May 17, 2019, 3:40:38 AM UTC'], [['download', 'google', 'search', 'history'], 'May 17, 2019, 3:38:42 AM UTC']]

# %%
print(sessions[1])
# Out:
# [[['check', 'dedicated', 'gpu', 'addictivetips'], 'May 16, 2019, 4:28:22 PM UTC'], [['gpu'], 'May 16, 2019, 4:28:13 PM UTC'], [['whats', 'difference', 'cpu', 'gpu', 'official'], 'May 16, 2019, 4:27:30 PM UTC'], [['cpu', 'gpu'], 'May 16, 2019, 4:27:20 PM UTC']]

# %%
print(sessions[3])
# Out:
# [[['audit', 'coursera', 'course', 'youtube'], 'May 16, 2019, 7:18:38 AM UTC'], [['audit', 'course', 'coursera'], 'May 16, 2019, 7:18:15 AM UTC'], [['github', 'shahariarrabbydeeplearningai', 'deeplearningai'], 'May 16, 2019, 7:13:11 AM UTC'], [['netflix', 'coursera', 'finish', 'andrew', 'ng', '1st', 'deep', 'learning'], 'May 16, 2019, 7:13:07 AM UTC'], [['get', 'deep', 'learning', 'andrew', 'ng', 'video', 'free', 'quora'], 'May 16, 2019, 7:12:51 AM UTC'], [['deep', 'learning', 'specialization', 'free', 'coursera'], 'May 16, 2019, 7:12:48 AM UTC'], [['datasets', '–', 'google', 'ai'], 'May 16, 2019, 7:01:07 AM UTC'], [['chrome', 'search', 'history', 'data', 'set'], 'May 16, 2019, 7:00:56 AM UTC'], [['coursera', 'online', 'course', 'credential', 'top', 'educator', 'join'], 'May 16, 2019, 6:45:00 AM UTC'], [['coursera'], 'May 16, 2019, 6:44:58 AM UTC'], [['ranjan', 'raj', 'imdb'], 'May 16, 2019, 6:41:43 AM UTC'], [['ranjan', 'raj'], 'May 16, 2019, 6:41:39 AM UTC']]

# %% [markdown]
# <b>Sessions are pre-processed now (without stop words)</b>

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
(sessions[0][0][0])
# Out:
# ['download', 'copy', 'google', 'search', 'history', 'business', 'insider']

# %% [markdown]
# <b>Sessions are pre-processed now (lemmatized, stop words removed, punctuations removed, lowercased)</b>

# %%
# from gensim.summarization import summarize

# %%
' '.join(word for word in sessions[0][1][0])
# Out:
# 'download entire google search history 2 easy step'

# %%
# text=''
# n=len(sessions)
# for j in range(n):
#     for i in range(len(sessions[j])):
#         text=text+' '.join(word for word in sessions[j][i][0])+'. '

# %%
# text='Learning these days is not limited to classroom lectures and training. It is the voyage of discovering more that encourages us to learn. School libraries play a very vital role in education system and are an essential part of school setup. My school library is a well set-up library. It is a very big library on the ground floor of the school that consists of several bookstands and cabinets. Books are precisely arranged in alphabetical order in these bookstands and cabinets. It has a wide range of books on diverse subjects, story books, comic books, biographies and magazines. At the entrance there is the librarian’s desk. There are rows of tables and chairs in the centre of the library for students to sit. Another section is the reference section of the library house for teachers. All the students visit library as per their classroom visit schedule. Library cards are to be carried to visit library. Our librarian is very helpful in locating and selecting books as per our needs. We are allowed to borrow one book at a time and the records for the same are maintained by the librarian. We need to ensure that the books are not damaged by us and are returned on time. Library is the best place to read without any disturbance. I love reading and writing so visiting the library for me is really very exciting. I can spend my entire day in the library.'

# %%
# text

# %%
# summarize(text)

# %%
' '.join(word for word in sessions[0][3][0])
# Out:
# 'download google search history'

# %%
s=''
for i in range(len(sessions[0])):
    s=s+(' '.join(word for word in sessions[0][i][0]))+'. '

# %%
s
# Out:
# 'download copy google search history business insider. download entire google search history 2 easy step. httpssupportgooglecomaccountsanswerdupmfakeanswerid3024190hlen. download google search history. '

# %%
strings=[]
for j in range(len(sessions)):
    string=''
    for i in range(len(sessions[j])):
        string=string+(' '.join(word for word in sessions[j][i][0]))+'. '
    strings.append(string)

# %%
strings[3]
# Out:
# 'audit coursera course youtube. audit course coursera. github shahariarrabbydeeplearningai deeplearningai. netflix coursera finish andrew ng 1st deep learning. get deep learning andrew ng video free quora. deep learning specialization free coursera. datasets – google ai. chrome search history data set. coursera online course credential top educator join. coursera. ranjan raj imdb. ranjan raj. '

# %%
import matplotlib.pyplot as plt
import gensim
import numpy as np
import spacy

from gensim.models import CoherenceModel, LdaModel, LsiModel, HdpModel
from gensim.models.wrappers import LdaMallet
from gensim.corpora import Dictionary
import pyLDAvis.gensim

import os, re, operator, warnings
warnings.filterwarnings('ignore')  # Let's not pay heed to them right now
# %matplotlib inline

import spacy
nlp = spacy.load("en")

my_stop_words = [u'say', u'\'s', u'Mr', u'be', u'said', u'says', u'saying']
for stopword in my_stop_words:
    lexeme = nlp.vocab[stopword]
    lexeme.is_stop = True
# Out:
# C:\Users\DELL.india\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
arr=[175,257,960,1046,1079,1431,1518,1796,2198,2420,3019,3240,3345,3419,3892,3898,3911,4187,4290,4309,4516]
topics=[]
for i in range(len(strings)):
    if i in arr:
        continue
    text=strings[i]
    doc = nlp(text)

    # we add some words to the stop word list
    texts, article, skl_texts = [], [], []
    for w in doc:
        # if it's not a stop word or punctuation mark, add it to our article!
        if w.text != '.' and not w.is_stop and not w.is_punct and not w.like_num:
            # we add the lematized version of the word
            article.append(w.lemma_)
        # if it's a new line, it means we're onto our next document
        if w.text == '.':
            skl_texts.append(' '.join(article))
            texts.append(article)
            article = []

    bigram = gensim.models.Phrases(texts)
    texts = [bigram[line] for line in texts]
    dictionary = Dictionary(texts)
    corpus = [dictionary.doc2bow(text) for text in texts]
    lsimodel = LsiModel(corpus=corpus, num_topics=10, id2word=dictionary)
#     print(i)
#     print(lsimodel.show_topics(num_topics=5))
    topics.append(lsimodel.show_topics(num_topics=1))

# %%
topics
# Out:
# [[(0,
#    '0.458*"download" + 0.458*"google" + 0.458*"history" + 0.458*"search" + 0.164*"business" + 0.164*"easy" + 0.164*"entire" + 0.164*"step" + 0.164*"insider" + 0.164*"copy"')],
#  [(0,
#    '0.704*"gpu" + 0.435*"cpu" + 0.276*"difference" + 0.276*"official" + 0.276*"s" + 0.170*"addictivetip" + 0.170*"check" + 0.170*"dedicated"')],
#  [(0, '0.707*"xpath" + 0.500*"w3schools" + 0.500*"xml"')],
#  [(0,
#    '0.483*"coursera" + 0.412*"learning" + 0.412*"deep" + 0.297*"ng" + 0.297*"andrew" + 0.247*"free" + 0.171*"course" + 0.165*"1st" + 0.165*"netflix" + 0.165*"finish"')],
#  [(0,
#    '0.535*"scrapy" + 0.535*"geek" + 0.267*"geeksforgeek" + 0.267*"scrap" + 0.267*"web" + 0.267*"python" + 0.267*"implement" + 0.267*"crawl"')],
#  [(0, '0.577*"number" + 0.577*"teach" + 0.577*"negative"')],
#  [(0,
# ...

# %%
len(topics)
# Out:
# 4519

# %%
topic=50
a=[]
b=[]
for i in range(1,len(topics[topic][0][1].split('"')),2):
#     print(topics[topic][0][1].split('"')[i])
    a.append(topics[topic][0][1].split('"')[i])
a
# Out:
# ['merwan',
#  'zomato',
#  'cake',
#  'chembur',
#  'stop',
#  'mumbai',
#  'shop',
#  'east',
#  'andheri',
#  'home']

# %%
final_topic=[]
final_topics=[]
for i in range(len(topics)):
    final_topic=[]
    for j in range(1,len(topics[i][0][1].split('"')),2):
        final_topic.append(topics[i][0][1].split('"')[j])
    final_topics.append(final_topic)
print(final_topics)
# Out:
# [['download', 'google', 'history', 'search', 'business', 'easy', 'entire', 'step', 'insider', 'copy'], ['gpu', 'cpu', 'difference', 'official', 's', 'addictivetip', 'check', 'dedicated'], ['xpath', 'w3schools', 'xml'], ['coursera', 'learning', 'deep', 'ng', 'andrew', 'free', 'course', '1st', 'netflix', 'finish'], ['scrapy', 'geek', 'geeksforgeek', 'scrap', 'web', 'python', 'implement', 'crawl'], ['number', 'teach', 'negative'], ['index', 'movie', 'animal', 'heyserverin', 'nocturnal', 'moviesbatch220nocturnal', 'ytsag', 'glass', 'film20185', 'film20184'], ['de', 'aana', 'chale', 'mp3', 'download', 'armaan', 'song', 'pyaar', 'malik', 'jamais'], ['iitb', 'gulmohar'], ['beratheon', 'baratheon'], ['wagner', 'richard', 'luther', 'wikipedia', 'luth', 'hochzeit', 'nietzsche', 'masterpiece', 'opera', 'wire'], ['google', 'form', 'sheet', 'html', 'embed', 'submit', 'spreadsheet', 'link', 'center', 'help'], ['mark', 'symbol', 'check', 'tick', 'insert', 'quick', 'guide', 'excel', 'computer', 'hop
# ...

# %%
final_topics[0]
# Out:
# ['download',
#  'google',
#  'history',
#  'search',
#  'business',
#  'easy',
#  'entire',
#  'step',
#  'insider',
#  'copy']

# %%
len(final_topics)
# Out:
# 4519

# %%
len(sessions)
# Out:
# 4540

# %%
sessions[2421]
# Out:
# [[['internal', 'page', 'iit', 'bombay'], 'Jul 26, 2017, 3:02:52 PM UTC'],
#  [['login', 'iitb', 'ac'], 'Jul 26, 2017, 3:02:41 PM UTC'],
#  [['httpsmfacebookcominsightiitbombayposts216147711748255'],
#   'Jul 26, 2017, 2:59:01 PM UTC'],
#  [['httpwwwcciitbacinengservicesengaccessingiitffromoutside'],
#   'Jul 26, 2017, 2:58:59 PM UTC'],
#  [['access', 'asc', 'iitb', 'outside'], 'Jul 26, 2017, 2:58:47 PM UTC'],
#  [['asc',
#    'external',
#    'online',
#    'fee',
#    'payment',
#    'iitb',
#    'portal',
#    'external',
#    'link'],
#   'Jul 26, 2017, 2:55:50 PM UTC'],
#  [['www1', 'asc', 'iitb'], 'Jul 26, 2017, 2:55:44 PM UTC'],
#  [['httpswww1iitbacinacademicoffdetailjsp'], 'Jul 26, 2017, 2:53:49 PM UTC'],
#  [['asc', 'iitb', 'ac'], 'Jul 26, 2017, 2:53:41 PM UTC'],
#  [['httpmusicpleeraudio'], 'Jul 26, 2017, 2:35:52 PM UTC'],
#  [['street', 'gold', 'mp3', 'download'], 'Jul 26, 2017, 2:35:48 PM UTC'],
#  [['httpmusicpleeraudio'], 'Jul 26, 2017, 1:44:24 PM UTC'],
# ...

# %%
# text=s
# doc=nlp(text)
# texts, article, skl_texts = [], [], []
# for w in doc:
#     # if it's not a stop word or punctuation mark, add it to our article!
#     if w.text != '.' and not w.is_stop and not w.is_punct and not w.like_num:
#         # we add the lematized version of the word
#         article.append(w.lemma_)
#     # if it's a new line, it means we're onto our next document
#     if w.text == '.':
#         skl_texts.append(' '.join(article))
#         texts.append(article)
#         article = []

# %%
# bigram = gensim.models.Phrases(texts)
# texts = [bigram[line] for line in texts]
# dictionary = Dictionary(texts)
# corpus = [dictionary.doc2bow(text) for text in texts]
# lsimodel = LsiModel(corpus=corpus, num_topics=10, id2word=dictionary)

# %%
# lsimodel.show_topics(num_topics=5)  # Showing only the top 5 topics
# Out:
# [(0,
#   '0.458*"history" + 0.458*"google" + 0.458*"download" + 0.458*"search" + 0.164*"insider" + 0.164*"copy" + 0.164*"step" + 0.164*"easy" + 0.164*"entire" + 0.164*"business"'),
#  (1,
#   '-0.408*"copy" + -0.408*"insider" + 0.408*"entire" + -0.408*"business" + 0.408*"easy" + 0.408*"step" + -0.000*"httpssupportgooglecomaccountsanswerdupmfakeanswerid3024190hlen" + -0.000*"history" + -0.000*"download" + 0.000*"search"'),
#  (2,
#   '-1.000*"httpssupportgooglecomaccountsanswerdupmfakeanswerid3024190hlen" + -0.000*"entire" + -0.000*"easy" + -0.000*"step" + 0.000*"google" + -0.000*"copy" + 0.000*"history" + 0.000*"search" + -0.000*"download" + -0.000*"insider"'),
#  (3,
#   '0.374*"easy" + 0.374*"entire" + 0.374*"step" + 0.374*"copy" + 0.374*"business" + 0.374*"insider" + -0.201*"download" + -0.201*"search" + -0.201*"history" + -0.201*"google"')]

# %%
# print(lsimodel.show_topics(num_topics=5))
# Out:
# [(0, '0.458*"history" + 0.458*"google" + 0.458*"download" + 0.458*"search" + 0.164*"insider" + 0.164*"copy" + 0.164*"step" + 0.164*"easy" + 0.164*"entire" + 0.164*"business"'), (1, '-0.408*"copy" + -0.408*"insider" + 0.408*"entire" + -0.408*"business" + 0.408*"easy" + 0.408*"step" + -0.000*"httpssupportgooglecomaccountsanswerdupmfakeanswerid3024190hlen" + -0.000*"history" + -0.000*"download" + 0.000*"search"'), (2, '-1.000*"httpssupportgooglecomaccountsanswerdupmfakeanswerid3024190hlen" + -0.000*"entire" + -0.000*"easy" + -0.000*"step" + 0.000*"google" + -0.000*"copy" + 0.000*"history" + 0.000*"search" + -0.000*"download" + -0.000*"insider"'), (3, '0.374*"easy" + 0.374*"entire" + 0.374*"step" + 0.374*"copy" + 0.374*"business" + 0.374*"insider" + -0.201*"download" + -0.201*"search" + -0.201*"history" + -0.201*"google"')]
